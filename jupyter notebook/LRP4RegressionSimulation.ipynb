# %% [markdown]
# # LRP for regression: A simulation study
#
# This simulation study aims to better understand the usage and interpretation of LRP for regression tasks.
# The simulated dataset is intended to very roughly imitate potential continuous ageing processes, specicifially in the brain.
# A 3D version of the pipeline below, was applied on multi-model MRIs, reported in [Hofmann et al. (2021)](DOI).
#
# ---
# Simon M. Hofmann <br>
# [*Max Planck Insitute for Human Cognitive and Brain Sciences, Leipzig, Germany*](https://www.cbs.mpg.de/employees/simonhofmann)<br>
#
# <[firstname].[lastname][at]pm.me> <br>
#
# `Last Update: 2021, Apri 7`
#
# ---

# %% [markdown]
# ![Pumpkins](../Pumpkin.png)

# %% [markdown]
# ## Import packages and modules <a class="tocSkip">

# %%
# Notebook related
from IPython.display import display, Image

# XDLreg
from xdlreg.utils import cprint
from xdlreg.run_simulation import run_simulation
from xdlreg.SimulationData import make_pumpkin, get_pumpkin_set, PumpkinHead, split_simulation_data
from xdlreg.PumpkinNet import get_model_data, load_trained_model, model_for_data_exists, plot_training_process, plot_prediction
from xdlreg.LRP.create_heatmaps import p2relevance, create_relevance_dict

# In-built packages
import os
import inspect
import string

# External packages
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import keras

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Run the full simulation pipeline

# %%
# Here for non-uniform dataset
run_simulation(path="..", n_samples=2000, uniform=False, target_bias=55., epochs=80, plot_n_heatmaps=20)
# Out:
# Run simulation on 2000 samples:
#
# Train PumpkinNet:
#
# No dataset found. Start creating it ...
# Start creating the pumpkin dataset of 2021-04-06_21-43_N-2000_non-uniform55.0 ...
# Creating whole dataset via parallel processing on 4 CPUs will take about: 0:09:00 [h:m:s] ...
# Created 2000 pumpkins in 0:12:02 [hh:min:sec].
#
# Processing time of _generate_data: 0:12:06 [h:m:s]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 98, 98, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 49, 49, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 49, 49, 16)        2320
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 25, 25, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 25, 25, 32)        4640
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 7, 7, 32)          2080
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 4, 4, 32)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                32832
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 60,593
# Trainable params: 60,593
# Non-trainable params: 0
# _________________________________________________________________
# Fit model on training data ...
# Train on 1600 samples, validate on 200 samples
# Epoch 1/80
# 1600/1600 [==============================] - 13s 8ms/step - loss: 249.7157 - mean_absolute_error: 13.0361 - val_loss: 255.5116 - val_mean_absolute_error: 13.2360
# Epoch 2/80
# 1600/1600 [==============================] - 13s 8ms/step - loss: 130.1580 - mean_absolute_error: 9.0800 - val_loss: 73.8438 - val_mean_absolute_error: 6.8189
# Epoch 3/80
# 1600/1600 [==============================] - 12s 8ms/step - loss: 59.4330 - mean_absolute_error: 6.1628 - val_loss: 50.0765 - val_mean_absolute_error: 5.5704
# Epoch 4/80
# 1600/1600 [==============================] - 13s 8ms/step - loss: 43.6766 - mean_absolute_error: 5.2413 - val_loss: 34.1434 - val_mean_absolute_error: 4.5991
# Epoch 5/80
# 1600/1600 [==============================] - 13s 8ms/step - loss: 37.3184 - mean_absolute_error: 4.8499 - val_loss: 63.9503 - val_mean_absolute_error: 6.9171
# Epoch 6/80
# 1600/1600 [==============================] - 12s 8ms/step - loss: 32.7030 - mean_absolute_error: 4.5675 - val_loss: 25.9973 - val_mean_absolute_error: 4.0891
# Epoch 7/80
# 1600/1600 [==============================] - 13s 8ms/step - loss: 24.9302 - mean_absolute_error: 3.9969 - val_loss: 37.1901 - val_mean_absolute_error: 4.9407
# Epoch 8/80
# 1600/1600 [==============================] - 12s 8ms/step - loss: 22.6155 - mean_absolute_error: 3.8058 - val_loss: 26.5278 - val_mean_absolute_error: 4.0616
# Epoch 9/80
# 1600/1600 [==============================] - 12s 8ms/step - loss: 18.7533 - mean_absolute_error: 3.4481 - val_loss: 17.1822 - val_mean_absolute_error: 3.3551
# Epoch 10/80
# 1600/1600 [==============================] - 12s 8ms/step - loss: 19.5083 - mean_absolute_error: 3.5184 - val_loss: 20.1213 - val_mean_absolute_error: 3.5049
# Epoch 11/80
# 1600/1600 [==============================] - 13s 8ms/step - loss: 16.0719 - mean_absolute_error: 3.1860 - val_loss: 21.5144 - val_mean_absolute_error: 3.6075
# Epoch 12/80
# 1600/1600 [==============================] - 13s 8ms/step - loss: 16.6886 - mean_absolute_error: 3.1921 - val_loss: 33.0399 - val_mean_absolute_error: 4.9223
# Epoch 13/80
# 1600/1600 [==============================] - 13s 8ms/step - loss: 17.1997 - mean_absolute_error: 3.2576 - val_loss: 13.7605 - val_mean_absolute_error: 2.9368
# Epoch 14/80
# 1600/1600 [==============================] - 13s 8ms/step - loss: 15.7755 - mean_absolute_error: 3.1329 - val_loss: 26.8953 - val_mean_absolute_error: 3.9955
# Epoch 15/80
# 1600/1600 [==============================] - 13s 8ms/step - loss: 15.5083 - mean_absolute_error: 3.0960 - val_loss: 12.9910 - val_mean_absolute_error: 2.8490
# Epoch 16/80
# 1600/1600 [==============================] - 13s 8ms/step - loss: 14.3361 - mean_absolute_error: 2.9768 - val_loss: 13.7709 - val_mean_absolute_error: 2.9693
# Epoch 17/80
# 1600/1600 [==============================] - 13s 8ms/step - loss: 14.8134 - mean_absolute_error: 3.0322 - val_loss: 13.1855 - val_mean_absolute_error: 2.8185
# Epoch 18/80
# 1600/1600 [==============================] - 13s 8ms/step - loss: 12.8926 - mean_absolute_error: 2.8325 - val_loss: 21.4154 - val_mean_absolute_error: 3.6604
# Epoch 19/80
# 1600/1600 [==============================] - 13s 8ms/step - loss: 11.9391 - mean_absolute_error: 2.7608 - val_loss: 13.2874 - val_mean_absolute_error: 2.8312
# Epoch 20/80
# 1600/1600 [==============================] - 12s 8ms/step - loss: 11.4500 - mean_absolute_error: 2.6691 - val_loss: 17.5224 - val_mean_absolute_error: 3.3957
# Epoch 21/80
# 1600/1600 [==============================] - 13s 8ms/step - loss: 11.3832 - mean_absolute_error: 2.6641 - val_loss: 10.6362 - val_mean_absolute_error: 2.5355
# Epoch 22/80
# 1600/1600 [==============================] - 13s 8ms/step - loss: 11.2587 - mean_absolute_error: 2.6422 - val_loss: 17.4462 - val_mean_absolute_error: 3.3242
# Epoch 23/80
# 1600/1600 [==============================] - 13s 8ms/step - loss: 13.3090 - mean_absolute_error: 2.8568 - val_loss: 13.3924 - val_mean_absolute_error: 2.8769
# Epoch 24/80
# 1600/1600 [==============================] - 13s 8ms/step - loss: 10.4568 - mean_absolute_error: 2.5409 - val_loss: 12.4198 - val_mean_absolute_error: 2.7477
# Epoch 25/80
# 1600/1600 [==============================] - 13s 8ms/step - loss: 9.1891 - mean_absolute_error: 2.3967 - val_loss: 13.6480 - val_mean_absolute_error: 2.8938
# Epoch 26/80
# 1600/1600 [==============================] - 13s 8ms/step - loss: 10.6159 - mean_absolute_error: 2.5630 - val_loss: 11.2498 - val_mean_absolute_error: 2.5495
# Epoch 27/80
# 1600/1600 [==============================] - 13s 8ms/step - loss: 9.4476 - mean_absolute_error: 2.3952 - val_loss: 11.0556 - val_mean_absolute_error: 2.5667
# Epoch 28/80
# 1600/1600 [==============================] - 13s 8ms/step - loss: 11.6276 - mean_absolute_error: 2.7015 - val_loss: 14.9732 - val_mean_absolute_error: 3.0663
# Epoch 29/80
# 1600/1600 [==============================] - 13s 8ms/step - loss: 8.1617 - mean_absolute_error: 2.2353 - val_loss: 10.4492 - val_mean_absolute_error: 2.5199
# Epoch 30/80
# 1600/1600 [==============================] - 13s 8ms/step - loss: 10.1109 - mean_absolute_error: 2.4687 - val_loss: 12.0372 - val_mean_absolute_error: 2.7647
# Epoch 31/80
# 1600/1600 [==============================] - 14s 9ms/step - loss: 8.2652 - mean_absolute_error: 2.2436 - val_loss: 10.5169 - val_mean_absolute_error: 2.5492
# Epoch 32/80
# 1600/1600 [==============================] - 13s 8ms/step - loss: 7.6094 - mean_absolute_error: 2.1822 - val_loss: 10.1443 - val_mean_absolute_error: 2.5166
# Epoch 33/80
# 1600/1600 [==============================] - 13s 8ms/step - loss: 8.3900 - mean_absolute_error: 2.2500 - val_loss: 22.0373 - val_mean_absolute_error: 3.8060
# Epoch 34/80
# 1600/1600 [==============================] - 13s 8ms/step - loss: 7.1521 - mean_absolute_error: 2.1077 - val_loss: 11.2592 - val_mean_absolute_error: 2.6310
# Epoch 35/80
# 1600/1600 [==============================] - 14s 8ms/step - loss: 7.3779 - mean_absolute_error: 2.1176 - val_loss: 15.3272 - val_mean_absolute_error: 3.1447
# Epoch 36/80
# 1600/1600 [==============================] - 14s 9ms/step - loss: 6.9064 - mean_absolute_error: 2.0691 - val_loss: 10.3188 - val_mean_absolute_error: 2.4865
# Epoch 37/80
# 1600/1600 [==============================] - 14s 9ms/step - loss: 6.8402 - mean_absolute_error: 2.0460 - val_loss: 11.2515 - val_mean_absolute_error: 2.6505
# Epoch 38/80
# 1600/1600 [==============================] - 13s 8ms/step - loss: 6.4457 - mean_absolute_error: 2.0005 - val_loss: 12.8919 - val_mean_absolute_error: 2.8298
# Epoch 39/80
# 1600/1600 [==============================] - 13s 8ms/step - loss: 6.3722 - mean_absolute_error: 1.9991 - val_loss: 12.5932 - val_mean_absolute_error: 2.8244
# Epoch 40/80
# 1600/1600 [==============================] - 14s 8ms/step - loss: 6.8844 - mean_absolute_error: 2.0559 - val_loss: 13.0283 - val_mean_absolute_error: 2.8932
# Epoch 41/80
# 1600/1600 [==============================] - 14s 9ms/step - loss: 6.7243 - mean_absolute_error: 2.0004 - val_loss: 12.8482 - val_mean_absolute_error: 2.8225
# Epoch 42/80
# 1600/1600 [==============================] - 14s 9ms/step - loss: 6.5904 - mean_absolute_error: 2.0062 - val_loss: 24.4775 - val_mean_absolute_error: 4.0837
# Epoch 43/80
# 1600/1600 [==============================] - 15s 9ms/step - loss: 6.1034 - mean_absolute_error: 1.9423 - val_loss: 15.5704 - val_mean_absolute_error: 3.1607
# Epoch 44/80
# 1600/1600 [==============================] - 14s 9ms/step - loss: 5.1101 - mean_absolute_error: 1.7853 - val_loss: 11.3863 - val_mean_absolute_error: 2.6871
# Epoch 45/80
# 1600/1600 [==============================] - 12s 8ms/step - loss: 5.6871 - mean_absolute_error: 1.8638 - val_loss: 13.5101 - val_mean_absolute_error: 2.8469
# Epoch 46/80
# 1600/1600 [==============================] - 12s 8ms/step - loss: 6.2233 - mean_absolute_error: 1.9495 - val_loss: 16.2984 - val_mean_absolute_error: 3.2349
# Epoch 47/80
# 1600/1600 [==============================] - 12s 7ms/step - loss: 5.3213 - mean_absolute_error: 1.8210 - val_loss: 11.1040 - val_mean_absolute_error: 2.6476
# Epoch 48/80
# 1600/1600 [==============================] - 11s 7ms/step - loss: 5.5675 - mean_absolute_error: 1.8396 - val_loss: 11.6575 - val_mean_absolute_error: 2.7271
# Epoch 49/80
# 1600/1600 [==============================] - 10s 6ms/step - loss: 5.8467 - mean_absolute_error: 1.8806 - val_loss: 10.5909 - val_mean_absolute_error: 2.5434
# Epoch 50/80
# 1600/1600 [==============================] - 11s 7ms/step - loss: 5.4901 - mean_absolute_error: 1.8284 - val_loss: 10.5785 - val_mean_absolute_error: 2.5713
# Epoch 51/80
# 1600/1600 [==============================] - 11s 7ms/step - loss: 5.6833 - mean_absolute_error: 1.8556 - val_loss: 10.4827 - val_mean_absolute_error: 2.5999
# Epoch 52/80
# 1600/1600 [==============================] - 10s 6ms/step - loss: 5.1181 - mean_absolute_error: 1.7969 - val_loss: 11.2785 - val_mean_absolute_error: 2.6118
# Epoch 53/80
# 1600/1600 [==============================] - 10s 7ms/step - loss: 4.7111 - mean_absolute_error: 1.6891 - val_loss: 12.4425 - val_mean_absolute_error: 2.7616
# Epoch 54/80
# 1600/1600 [==============================] - 10s 6ms/step - loss: 4.3270 - mean_absolute_error: 1.6168 - val_loss: 13.4564 - val_mean_absolute_error: 2.8901
# Epoch 55/80
# 1600/1600 [==============================] - 11s 7ms/step - loss: 4.6827 - mean_absolute_error: 1.6768 - val_loss: 12.0011 - val_mean_absolute_error: 2.6960
# Epoch 56/80
# 1600/1600 [==============================] - 10s 7ms/step - loss: 4.5622 - mean_absolute_error: 1.6644 - val_loss: 14.3906 - val_mean_absolute_error: 2.9949
# Epoch 57/80
# 1600/1600 [==============================] - 10s 6ms/step - loss: 4.6883 - mean_absolute_error: 1.6697 - val_loss: 10.9048 - val_mean_absolute_error: 2.6154
# Epoch 58/80
# 1600/1600 [==============================] - 10s 6ms/step - loss: 4.9936 - mean_absolute_error: 1.7622 - val_loss: 13.9633 - val_mean_absolute_error: 2.9781
# Epoch 59/80
# 1600/1600 [==============================] - 10s 7ms/step - loss: 4.2225 - mean_absolute_error: 1.5900 - val_loss: 15.7480 - val_mean_absolute_error: 3.1854
# Epoch 60/80
# 1600/1600 [==============================] - 10s 6ms/step - loss: 5.3387 - mean_absolute_error: 1.7895 - val_loss: 14.0170 - val_mean_absolute_error: 3.0256
# Epoch 61/80
# 1600/1600 [==============================] - 10s 6ms/step - loss: 4.5170 - mean_absolute_error: 1.6544 - val_loss: 12.2398 - val_mean_absolute_error: 2.7794
# Epoch 62/80
# 1600/1600 [==============================] - 12s 7ms/step - loss: 4.9940 - mean_absolute_error: 1.7532 - val_loss: 11.5345 - val_mean_absolute_error: 2.7622
# Epoch 63/80
# 1600/1600 [==============================] - 11s 7ms/step - loss: 4.7096 - mean_absolute_error: 1.6859 - val_loss: 13.8011 - val_mean_absolute_error: 2.8957
# Epoch 64/80
# 1600/1600 [==============================] - 11s 7ms/step - loss: 4.6056 - mean_absolute_error: 1.6722 - val_loss: 10.8887 - val_mean_absolute_error: 2.6222
# Epoch 65/80
# 1600/1600 [==============================] - 11s 7ms/step - loss: 4.8574 - mean_absolute_error: 1.7015 - val_loss: 11.0049 - val_mean_absolute_error: 2.6186
# Epoch 66/80
# 1600/1600 [==============================] - 10s 6ms/step - loss: 3.7948 - mean_absolute_error: 1.5193 - val_loss: 10.9558 - val_mean_absolute_error: 2.5820
# Epoch 67/80
# 1600/1600 [==============================] - 10s 6ms/step - loss: 3.7866 - mean_absolute_error: 1.5187 - val_loss: 12.5329 - val_mean_absolute_error: 2.8194
# Epoch 68/80
# 1600/1600 [==============================] - 10s 6ms/step - loss: 4.4632 - mean_absolute_error: 1.6426 - val_loss: 14.4916 - val_mean_absolute_error: 3.0338
# Epoch 69/80
# 1600/1600 [==============================] - 10s 6ms/step - loss: 4.2539 - mean_absolute_error: 1.6060 - val_loss: 12.4519 - val_mean_absolute_error: 2.7172
# Epoch 70/80
# 1600/1600 [==============================] - 11s 7ms/step - loss: 4.2124 - mean_absolute_error: 1.5883 - val_loss: 25.6917 - val_mean_absolute_error: 4.2941
# Epoch 71/80
# 1600/1600 [==============================] - 10s 6ms/step - loss: 4.6521 - mean_absolute_error: 1.6765 - val_loss: 13.4007 - val_mean_absolute_error: 2.8440
# Epoch 72/80
# 1600/1600 [==============================] - 11s 7ms/step - loss: 3.6093 - mean_absolute_error: 1.4756 - val_loss: 12.3268 - val_mean_absolute_error: 2.7674
# Epoch 73/80
# 1600/1600 [==============================] - 11s 7ms/step - loss: 4.5898 - mean_absolute_error: 1.6784 - val_loss: 11.1632 - val_mean_absolute_error: 2.6168
# Epoch 74/80
# 1600/1600 [==============================] - 10s 7ms/step - loss: 3.7290 - mean_absolute_error: 1.5005 - val_loss: 12.2582 - val_mean_absolute_error: 2.7968
# Epoch 75/80
# 1600/1600 [==============================] - 10s 6ms/step - loss: 3.5087 - mean_absolute_error: 1.4579 - val_loss: 12.0597 - val_mean_absolute_error: 2.7076
# Epoch 76/80
# 1600/1600 [==============================] - 10s 6ms/step - loss: 3.8612 - mean_absolute_error: 1.5191 - val_loss: 10.8371 - val_mean_absolute_error: 2.5511
# Epoch 77/80
# 1600/1600 [==============================] - 10s 6ms/step - loss: 4.1101 - mean_absolute_error: 1.5819 - val_loss: 11.3986 - val_mean_absolute_error: 2.6750
# Epoch 78/80
# 1600/1600 [==============================] - 10s 6ms/step - loss: 4.1543 - mean_absolute_error: 1.5781 - val_loss: 10.7560 - val_mean_absolute_error: 2.5895
# Epoch 79/80
# 1600/1600 [==============================] - 10s 6ms/step - loss: 3.7049 - mean_absolute_error: 1.4964 - val_loss: 11.5400 - val_mean_absolute_error: 2.6171
# Epoch 80/80
# 1600/1600 [==============================] - 10s 6ms/step - loss: 3.8650 - mean_absolute_error: 1.5307 - val_loss: 11.8170 - val_mean_absolute_error: 2.7121
#
# Evaluate PumpkinNet_2000_non-uniform55.0 on test data ...
# 200/200 [==============================] - 1s 3ms/step
# test loss, test performance: [13.771084900626738, 2.9101648902893067]
#
# Processing time of train_simulation_model: 0:16:01 [h:m:s]
#
# Create relevance maps (LRP) for PumpkinNet_2000_non-uniform55.0:
#
# Found & loaded following dataset file: 2021-04-06_21-43_N-2000_non-uniform55.0.pkl ...
#
# Plot heatmaps for 20 random tori ('pumpkins'):
#
# Found & loaded following dataset file: 2021-04-06_21-43_N-2000_non-uniform55.0.pkl ...

# %% [markdown]
# ## Get the simulation data

# %%
# Get Pumpkin dataset
model_name = "PumpkinNet_2000_non-uniform55.0"  # for setup above in run_simulation()
# Alternatively use:
# model = load_trained_model()  # to browse for trained model
# model_name = model.name

pumpkins_set = get_model_data(model_name=model_name, for_keras=False)
# Out:
# Found & loaded following dataset file: 2021-04-06_21-43_N-2000_non-uniform55.0.pkl ...

# %% [markdown]
# ### Explore the data object

# %%
print("Attributes of dataset object:", *[attri for attri in dir(pumpkins_set) if not attri.startswith("_")], sep="\n * .")  # what does the class PumpkinSet contain
cprint(f"\nDataset name: {pumpkins_set.name}", 'b')
print("Number of samples:", pumpkins_set.n_samples)
print("Age Distrubtion:", pumpkins_set.age_distribution)
# Out:
# Attributes of dataset object:
#  * .age_bias
#  * .age_distribution
#  * .data
#  * .data2numpy
#  * .display_distrubtion
#  * .is_uniform
#  * .n_samples
#  * .name
#  * .save
#
# Dataset name: 2021-04-06_21-43_N-2000_non-uniform55.0
# Number of samples: 2000
# Age Distrubtion: [34. 55. 56. ... 51. 28. 59.]

# %% [markdown]
# #### Data distrubtion

# %%
# Plot the distribution
pumpkins_set.display_distrubtion()

# %% [markdown]
# #### A sample pumpkin

# %%
# # Take one pumpkin
phead = pumpkins_set.data[0]  # class PumpkinHead 

def introduce_yourself(pumpkin):
    cprint(f"Hi, I am {pumpkin.name} and I am {pumpkin.age} years old.", 'y')

introduce_yourself(phead)
print("Number of atrophies:", phead.n_atrophies)
print("Number of lesions:", phead.n_lesions)
print("Image.shape:", phead.pumpkin_brain.shape)
# class PumpkinHead also includes the position of the atrophies & lesions

# Plot the pumpkin
phead.exhibition()
# Out:
# Hi, I am PHKEs072908955 and I am 34.0 years old.
# Number of atrophies: 171
# Number of lesions: 0
# Image.shape: (98, 98)

# %% [markdown]
# #### How do they grow?
# First we need a standard pumpkin. This is a blue-print (with some slight variation) for each instantiation of a *real* pumpkin

# %%
# print(inspect.getsource(make_pumpkin))  # explore the function behind the pumpkin blueprint

# Create standard pumpkin
standard_pumpkin = make_pumpkin(age=66)
standard_pumpkin_toddler = make_pumpkin(age=2)

# Plot it
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
ax1.imshow(standard_pumpkin, cmap="gist_heat")
ax1.set_title("Standard pumpkin")
ax2.imshow(standard_pumpkin_toddler, cmap="gist_heat")
ax2.set_title("Toddler pumpkin")
plt.show()

# %% [markdown]
# Note, we don't have *minors* in our current dataset. However, setting the `min_age` lower in `xdlreg.SimulationData.py` would also allow for '*developemental*' studies. That is, the size of a head is only a function of younger ages (< 20 years). For *adult pumpkins*, the head size is constant (+ random variation), ignoring the effect of *atrophies*.
#
# We let the pumpkin grow with the class `PumpkinHead` (see below).

# %%
# Explore the class PumpkinHead 
# print(inspect.getsource(PumpkinHead))

# %%
# Oldy
pumpy = PumpkinHead(age=77, name="Halloween senior")
introduce_yourself(pumpy)
pumpy.exhibition()

# Youngster
pumpster = PumpkinHead(age=22, name="Halloween junior")
introduce_yourself(pumpster)
pumpster.exhibition()

# Image intensities
_ = plt.hist(pumpy.pumpkin_brain.flatten(), bins=200, log=True, label=pumpy.name, alpha=.5)
_ = plt.hist(pumpster.pumpkin_brain.flatten(), bins=200, log=True, label=pumpster.name, alpha=.5)
plt.legend()
plt.show()
# Out:
# Hi, I am Halloween senior and I am 77 years old.
# Hi, I am Halloween junior and I am 22 years old.

# %% [markdown]
# #### Number of lesions & atrophies
# Both the numbers of lesions and atrophies are functions of age

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=(8, 8))
for pumpkin in pumpkins_set.data:
    ax1.plot(pumpkin.age, pumpkin.n_atrophies, "o", alpha=.5)
    ax2.plot(pumpkin.age, pumpkin.n_lesions, "o", alpha=.5)
ax1.set_ylabel("N atrophies")
ax2.set_xlabel("Age")
ax2.set_ylabel("N lesions")
plt.tight_layout()

# %% [markdown]
# The number of *atrophies* is linearly increasing with age. In contrast, the number of *lesions* is a non-linear step-function of age.

# %% [markdown]
# ## Get the prediction model

# %%
# Load model
model = load_trained_model(model_name=model_name)
# model = load_trained_model(model_name=model_for_data_exists(dataset_name=pumpkins_set.name, epochs=80))  # set correct epochs as above

# Model Summary
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 98, 98, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 49, 49, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 49, 49, 16)        2320
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 25, 25, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 25, 25, 32)        4640
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 7, 7, 32)          2080
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 4, 4, 32)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                32832
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 60,593
# Trainable params: 60,593
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training process

# %%
# Plot training process
plot_fn = plot_training_process(_model=model)
display(Image(filename=plot_fn))

# %% [markdown]
# ### Model performance

# %%
# Prep data as model input
x, y = pumpkins_set.data2numpy(for_keras=True)
xtest, ytest = split_simulation_data(xdata=x, ydata=y, only_test=True)

# Predict on test set:
preds = model.predict(xtest)

# Model performance
perform = np.mean(np.abs(preds.squeeze() - ytest))
r = np.corrcoef(x=preds.flatten(), y=ytest)[0, 1]

cprint(f"\n{model.name} has a MAE of {perform:.2f} ({'R^2'}={r**2:.2f})\n", 'b')
# Out:
# PumpkinNet_2000_non-uniform55.0 has a MAE of 2.91 (R^2=0.95)

# %%
# Plot predictions 
plot_fns = plot_prediction(_model=model, xdata=xtest, ydata=ytest)

# Predictions vs true age
display(Image(filename=plot_fns[0]))

# # Plotted in this way:
# sns.jointplot(x=preds.squeeze(), y=ytest, kind="reg", height=10,
#               marginal_kws=dict(bins=int(round((ytest.max() - ytest.min()) / 3))),
#               xlim=(np.min(preds) - 10, np.max(preds) + 10),
#               ylim=(np.min(ytest) - 10, np.max(ytest) + 10)).plot_joint(
#     sns.kdeplot, zorder=0, n_levels=6).set_axis_labels("Predictions", "True-AGE")

# True age vs prediction-error:
display(Image(filename=plot_fns[1]))

# %% [markdown]
# ## Apply LRP analysis on the regression model

# %%
# Model output bias is important for the interpretation of the following relevance maps
model_output_bias = model.layers[-1].get_weights()[1].item()

# Compare to the mean age in the dataset and to the prediction-'bias'
cprint(f"Model output bias is: {model_output_bias:.2f}", 'b')
print(f"Mean age of dataset is: {ytest.mean():.2f}")
cprint(f"Mean prediction on test set is: {preds.mean():.2f}", 'y')
# Out:
# Model output bias is: 50.83
# Mean age of dataset is: 50.05
# Mean prediction on test set is: 49.36

# %%
# Load relevance maps for tori in test set
relmaps = create_relevance_dict(model_name=model.name, subset="test")

# %%
# Plot the sum-relevance per torus ('pumpkin') over the corresponding model predictions. 
ax = sns.regplot(x=preds, y=[rmap.sum() for rmap in relmaps])
plt.hlines(0, xmin=ytest.min(), xmax=ytest.max(), colors="black", ls="dashed", alpha=.7)
plt.vlines(x=preds.mean(), ymin=ax.get_ylim()[0], ymax=ax.get_ylim()[1], colors="red", ls="dotted", 
           alpha=.7, label="mean prediction")
plt.xlabel("prediction")
plt.ylabel("sum relevance")
plt.legend()
plt.tight_layout()

# %%
# # Get already computed LRP heatmaps of 20 subjects 
pointer = True  # toggle here, if pointer (not) requested,

list_of_LRP_images = os.listdir(os.path.join(p2relevance(), model.name, "plots"))
list_of_LRP_images = [name for name in list_of_LRP_images if ((".png" in name) and (pointer is ("pointer" in name)))]  # remove non-*.png's
list_of_ages = [name.split("_")[2] for name in list_of_LRP_images]  # get age information from list
sorted_list_of_LRP_images = np.array(list_of_LRP_images)[np.argsort(list_of_ages)]  # get sort index w.r.t. age

# Display LRP heatmaps
for LRP_image_file in sorted_list_of_LRP_images:
    if ".png" in LRP_image_file:
        cprint(LRP_image_file.rstrip("_pointer.png"), 'b')
        display(Image(filename=os.path.join(p2relevance(), model.name, "plots", LRP_image_file)))
# Out:
# LRP_S16_age-24.0_pred-24.8
# LRP_S0_age-24.0_pred-22.9
# LRP_S6_age-28.0_pred-27.7
# LRP_S12_age-29.0_pred-26.3
# LRP_S4_age-31.0_pred-25.9
# LRP_S9_age-34.0_pred-29.9
# LRP_S5_age-37.0_pred-37.8
# LRP_S10_age-40.0_pred-38.1
# LRP_S18_age-41.0_pred-40.2
# LRP_S17_age-49.0_pred-54.0
# LRP_S14_age-50.0_pred-53.8
# LRP_S3_age-50.0_pred-49.6
# LRP_S7_age-51.0_pred-55.0
# LRP_S11_age-53.0_pred-56.7
# LRP_S13_age-54.0_pred-50.4
# LRP_S19_age-56.0_pred-57.5
# LRP_S1_age-58.0_pred-58.7
# LRP_S2_age-58.0_pred-60.7
# LRP_S15_age-60.0_pred-60.5
# LRP_S8_age-66.0_pred-58.5
